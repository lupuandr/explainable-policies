# %%
import jax
import jax.numpy as jnp
import flax.linen as nn
import numpy as np
import optax
from flax.linen.initializers import constant, orthogonal
from typing import Sequence, NamedTuple, Any
from flax.training.train_state import TrainState
import distrax
import gymnax
from gymnax.wrappers.purerl import LogWrapper, FlattenObservationWrapper
import time

import sys
sys.path.insert(0, '..')  # adds the root directory to the path

from policy_distillation.behaviour_clone import BCAgent, Transition, make_train
import matplotlib.pyplot as plt

# %% [markdown]
# # Meta-learning the Dataset

# %% [markdown]
# ## Setup

# %%
from evosax import OpenES, ParameterReshaper

env_name = "MNISTBandit-bsuite"
env, env_params = gymnax.make(env_name)
env = FlattenObservationWrapper(env)
env = LogWrapper(env)

n_actions = env.action_space(env_params).n

config = {
    "LR": 5e-3,  # 5e-3      # 2.5e-2 to 5e-2 brings BC loss to ~0 for UPDATE_EPOCHS=10 and up to 100 states/action
    "NUM_ENVS": 4,   #8 # Num eval envs
    "NUM_STEPS": 512,   #128 # Max num eval steps per env
    "UPDATE_EPOCHS": 20,  # Num BC gradient steps
    "MAX_GRAD_NORM": 0.5,
    "ACTIVATION": "tanh",
    "WIDTH" : 64,
    "ENV_NAME": env_name,
    "ANNEAL_LR": True,
    "GREEDY_ACT": True,  # Whether to use greedy act in env or sample
    "ENV_PARAMS" : {}
}

es_config = {
    "popsize": 256,  # Num of candidates
    "dataset_size": n_actions * 1, #10 #20000,  # Num of (s,a) pairs (split evenly across actions)
    "rollouts_per_candidate": 4,  #32 Num of BC policies trained per candidate
    "n_generations": 100,
    "log_interval": 1,
}

params = jnp.zeros(
    (es_config["dataset_size"], *env.observation_space(env_params).shape)
)
param_reshaper = ParameterReshaper(params)

rng = jax.random.PRNGKey(0)
# Out:
# ParameterReshaper: 2 devices detected. Please make sure that the ES population size divides evenly across the number of devices to pmap/parallelize over.
# ParameterReshaper: 7840 parameters detected for optimization.

# %% [markdown]
# ## Sampling real data

# %%
from tqdm import tqdm
rng, reset_rng = jax.random.split(rng)
obs, env_state = env.reset(reset_rng, env_params)

obs_list = []
action_list = []
dones_list = []

# Small chance of not gathering enough data, but it doesn't matter in practice
for t in tqdm(range(es_config["dataset_size"] * 10)):
    rng, rng_act, rng_step = jax.random.split(rng, 3)
    action = jax.random.choice(rng_act, a=jnp.arange(n_actions))
    
    obs, env_state, reward, done, info = env.step(rng_step, env_state, action, env_params)
    obs_list.append(obs)    
    action_list.append(env_state.env_state.correct_label)
    
action_list = jnp.array(action_list)
obs_list = jnp.array(obs_list)

dataset = []
dataset_labels = []
for a in range(n_actions):
    obs_for_action = obs_list[action_list == a]
    dataset.append(obs_for_action[0:es_config["dataset_size"]//n_actions])
    dataset_labels.extend([a]*(es_config["dataset_size"]//n_actions))
    
sampled_data = jnp.array(dataset).flatten()
print(sampled_data.shape)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:02<00:00, 33.62it/s]
# (7840,)

# %%
# for i in range(0,1000,100):
#     print(dataset_labels[i])
#     plt.imshow(param_reshaper.reshape_single(sampled_data)[i].reshape((28,28)), cmap="Greys")
#     plt.show()

# %% [markdown]
# ## Initialize Strategy

# %%
# Initialize OpenES Strategy
# rng = jax.random.PRNGKey(0)
rng, rng_init = jax.random.split(rng)

strategy = OpenES(
    popsize=es_config["popsize"],
    num_dims=param_reshaper.total_params,
    opt_name="adam",
    maximize=True,
#     sigma_init=0.005
)

es_params = strategy.default_params
# es_params = es_params.replace(init_max=1.0, init_min=-1.0)
state = strategy.initialize(rng_init, es_params)

# Replace state mean with real observations
state = state.replace(mean = sampled_data)


def get_action_labels(d_size, n_actions):
    action_labels = jnp.array([i % n_actions for i in range(d_size)])
    action_labels = action_labels.sort()
    return action_labels


# Set up vectorized fitness function
train_fn = make_train(config)
action_labels = get_action_labels(es_config["dataset_size"], n_actions)


def single_seed_BC(rng_input, dataset):
    out = train_fn(dataset, action_labels, rng_input)
    return out  # ["metrics"]['returned_episode_returns'].mean()


multi_seed_BC = jax.vmap(single_seed_BC, in_axes=(0, None))  # Vectorize over seeds
train_and_eval = jax.jit(jax.vmap(multi_seed_BC, in_axes=(None, 0)))  # Vectorize over datasets

if len(jax.devices()) > 1:
    train_and_eval = jax.pmap(train_and_eval, in_axes=(None, 0))

# %% [markdown]
# ## Run OpenES loop

# %%
start = time.time()
lap_start = start
fitness_over_gen = []
max_fitness_over_gen = []
for gen in range(es_config["n_generations"]):
    # Gen new dataset
    rng, rng_ask, rng_inner = jax.random.split(rng, 3)
    datasets, state = jax.jit(strategy.ask)(rng_ask, state, es_params)
    # Eval fitness
    batch_rng = jax.random.split(rng_inner, es_config["rollouts_per_candidate"])
    # Preemptively overwrite to reduce memory load
    out = None
    returns = None
    dones = None
    fitness = None
    shaped_datasets = None

    with jax.disable_jit(False):
        shaped_datasets = param_reshaper.reshape(datasets)
        out = train_and_eval(batch_rng, shaped_datasets)

        returns = out["metrics"]["returned_episode_returns"]  # dim=(popsize, rollouts, num_steps, num_envs)
        dones = out["metrics"]["returned_episode"]  # same dim, True for last steps, False otherwise
        
        # Division by zero, you idiot
        fitness = (returns * dones).sum(axis=(-1, -2, -3)) / dones.sum(axis=(-1, -2, -3))  # fitness, dim = (popsize)
        fitness = fitness.flatten()    # Necessary if pmap-ing to 2+ devices

    # Update ES strategy with fitness info
    state = jax.jit(strategy.tell)(datasets, fitness, state, es_params)
    fitness_over_gen.append(fitness.mean())
    max_fitness_over_gen.append(fitness.max())

    if gen % es_config["log_interval"] == 0 or gen == 0:
        lap_end = time.time()
        if len(jax.devices()) > 1:
            bc_loss = out["metrics"]["bc_loss"][:,:,:,-1]
            bc_acc = out["metrics"]["bc_accuracy"][:,:,:,-1]
        else:
            bc_loss = out["metrics"]["bc_loss"][:,:,-1]
            bc_acc = out["metrics"]["bc_accuracy"][:,:,-1]
        
        print(
            f"Gen: {gen}, Fitness: {fitness.mean():.2f} +/- {fitness.std():.2f}, "
            + f"Best: {state.best_fitness:.2f}, BC loss: {bc_loss.mean():.2f} +/- {bc_loss.std():.2f}, "
            + f"BC acc: {bc_acc.mean():.2f} +/- {bc_acc.std():.2f}, Lap time: {lap_end-lap_start:.1f}s"
        )
        lap_start = lap_end
print(f"Total time: {(lap_end-start)/60:.1f}min")
# Out:
# Gen: 0, Fitness: -0.73 +/- 0.01, Best: -0.71, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 5.8s
# Gen: 1, Fitness: -0.73 +/- 0.01, Best: -0.71, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 2, Fitness: -0.73 +/- 0.01, Best: -0.71, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 3, Fitness: -0.72 +/- 0.01, Best: -0.70, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 4, Fitness: -0.72 +/- 0.00, Best: -0.70, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 5, Fitness: -0.72 +/- 0.00, Best: -0.70, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 6, Fitness: -0.71 +/- 0.00, Best: -0.69, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 7, Fitness: -0.70 +/- 0.01, Best: -0.69, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 8, Fitness: -0.71 +/- 0.00, Best: -0.69, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 9, Fitness: -0.69 +/- 0.00, Best: -0.68, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 10, Fitness: -0.69 +/- 0.00, Best: -0.68, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 11, Fitness: -0.70 +/- 0.00, Best: -0.68, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 12, Fitness: -0.69 +/- 0.00, Best: -0.68, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 13, Fitness: -0.69 +/- 0.00, Best: -0.67, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 14, Fitness: -0.68 +/- 0.00, Best: -0.67, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 15, Fitness: -0.69 +/- 0.00, Best: -0.67, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 16, Fitness: -0.70 +/- 0.00, Best: -0.67, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 17, Fitness: -0.68 +/- 0.00, Best: -0.66, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 18, Fitness: -0.68 +/- 0.00, Best: -0.66, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 19, Fitness: -0.68 +/- 0.00, Best: -0.66, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 20, Fitness: -0.67 +/- 0.00, Best: -0.66, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 21, Fitness: -0.70 +/- 0.00, Best: -0.66, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 22, Fitness: -0.66 +/- 0.00, Best: -0.65, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 23, Fitness: -0.66 +/- 0.00, Best: -0.65, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 24, Fitness: -0.68 +/- 0.00, Best: -0.65, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 25, Fitness: -0.68 +/- 0.00, Best: -0.65, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 26, Fitness: -0.67 +/- 0.00, Best: -0.65, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 27, Fitness: -0.68 +/- 0.00, Best: -0.65, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 28, Fitness: -0.67 +/- 0.00, Best: -0.65, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 29, Fitness: -0.67 +/- 0.00, Best: -0.65, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 30, Fitness: -0.68 +/- 0.00, Best: -0.65, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 31, Fitness: -0.68 +/- 0.00, Best: -0.65, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 32, Fitness: -0.66 +/- 0.00, Best: -0.65, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 33, Fitness: -0.66 +/- 0.00, Best: -0.65, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 34, Fitness: -0.67 +/- 0.00, Best: -0.65, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 35, Fitness: -0.66 +/- 0.00, Best: -0.65, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 36, Fitness: -0.67 +/- 0.00, Best: -0.65, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 37, Fitness: -0.65 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 38, Fitness: -0.65 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 39, Fitness: -0.67 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 40, Fitness: -0.66 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 41, Fitness: -0.66 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 42, Fitness: -0.67 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 43, Fitness: -0.66 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 44, Fitness: -0.66 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 45, Fitness: -0.67 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 46, Fitness: -0.67 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 47, Fitness: -0.66 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 48, Fitness: -0.67 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 49, Fitness: -0.67 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 50, Fitness: -0.65 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 51, Fitness: -0.67 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 52, Fitness: -0.66 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 53, Fitness: -0.67 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 54, Fitness: -0.65 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 55, Fitness: -0.66 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 56, Fitness: -0.67 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 57, Fitness: -0.67 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 58, Fitness: -0.65 +/- 0.00, Best: -0.64, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 59, Fitness: -0.64 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 60, Fitness: -0.64 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 61, Fitness: -0.67 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 62, Fitness: -0.66 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 63, Fitness: -0.67 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 64, Fitness: -0.64 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 65, Fitness: -0.66 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 66, Fitness: -0.65 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 67, Fitness: -0.67 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 68, Fitness: -0.66 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 69, Fitness: -0.66 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 70, Fitness: -0.66 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 71, Fitness: -0.66 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 72, Fitness: -0.67 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 73, Fitness: -0.65 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 74, Fitness: -0.65 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 75, Fitness: -0.65 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 76, Fitness: -0.65 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 77, Fitness: -0.64 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 78, Fitness: -0.66 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 79, Fitness: -0.65 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 80, Fitness: -0.66 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 81, Fitness: -0.67 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 82, Fitness: -0.66 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 83, Fitness: -0.66 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 84, Fitness: -0.66 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 85, Fitness: -0.65 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 86, Fitness: -0.65 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 87, Fitness: -0.65 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 88, Fitness: -0.66 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 89, Fitness: -0.67 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 90, Fitness: -0.65 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 91, Fitness: -0.66 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 92, Fitness: -0.67 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 93, Fitness: -0.65 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 94, Fitness: -0.65 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 95, Fitness: -0.66 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 96, Fitness: -0.66 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 97, Fitness: -0.67 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 98, Fitness: -0.65 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Gen: 99, Fitness: -0.66 +/- 0.00, Best: -0.63, BC loss: 0.00 +/- 0.00, BC acc: 1.00 +/- 0.00, Lap time: 0.6s
# Total time: 1.1min

# %%
from scipy.signal import savgol_filter
# savgol_filter(y, 20, 3)

y = fitness_over_gen
plt.plot(fitness_over_gen, label="Mean fitness")
y = max_fitness_over_gen
plt.plot(max_fitness_over_gen, label="Max fitness")
plt.title(f"Fitness in {config['ENV_NAME']} with N={es_config['dataset_size']} examples")
plt.ylabel("Fitness (Return)")
plt.xlabel("Meta-learner Generations")
plt.legend()
plt.show()

# %%
def reshape(arr):
    """Removes extra dim due to pmap"""
    dims = arr.shape
    arr = arr.reshape(-1,dims[-2],dims[-1])
    return arr

fig, ax = plt.subplots(2, 1)
for i in range(es_config["popsize"]):
    acc = reshape(out["metrics"]["bc_accuracy"])[i].mean(axis=0)
    ax[0].plot(acc)
    ax[0].set_ylabel("Accuracy")

    loss = reshape(out["metrics"]["bc_loss"])[i].mean(axis=0)
    ax[1].plot(loss)
    ax[1].set_ylabel("BC Loss")
    ax[1].set_xlabel("Gradient steps")

# %% [markdown]
# ## Double check policy return

# %%
P = es_config["popsize"]
final_datasets_reshaped = param_reshaper.reshape(datasets)

best = fitness.argmax()

if len(jax.devices()) > 1:
    best_idx = (best // (P//2), best % (P//2))
else:
    best_idx = (best % (P//2))

final_dataset = final_datasets_reshaped[best_idx]

train_state = out["runner_state"][0]
# Note: if multiple rollouts / candidate, pick first rollout
if len(jax.devices()) > 1:
    f = lambda x : x[best_idx[0], best_idx[1], 0]
else:
    f = lambda x : x[best_idx, 0]
best_params = jax.tree_util.tree_map(f, train_state.params)

best_ret = returns[best_idx]
best_dones = dones[best_idx]

best_mean_ret  = (best_ret * best_dones).sum(axis=(-1, -2)) /best_dones.sum(axis=(-1, -2))
print("Best mean return per rollout", best_mean_ret)

# %%
## Play policy

# env, env_params = gymnax.make(config["ENV_NAME"])
# env = FlattenObservationWrapper(env)
# env = LogWrapper(env)

# n_actions = env.action_space(env_params).n

# rng = jax.random.PRNGKey(42)
# rng, reset_rng = jax.random.split(rng)
# obs, env_state = env.reset(reset_rng, env_params)

# rewards_per_ep = []

# for t in tqdm(range(512)):
#     rng, rng_act, rng_step = jax.random.split(rng, 3)
    
#     pi = train_state.apply_fn(best_params, obs)
#     action = pi.argmax(axis=-1)
    
#     obs, env_state, reward, done, info = env.step(rng_step, env_state, action, env_params) 
#     rewards_per_ep.append(reward)
#     if done:
#         ep_ret = jnp.array(rewards_per_ep).sum()
#         print("Ep return: ", ep_ret)
#         rewards_per_ep = []

# %%
points_per_class = es_config["dataset_size"] // n_actions
points_per_class = min(10,points_per_class)

fig, ax = plt.subplots(10, points_per_class, figsize=(10,10))

for i, synth_state in enumerate(param_reshaper.reshape_single(state.mean)):
    if i == 100:
        break
    img = synth_state.reshape(28,28)
    ax[i//points_per_class, i%points_per_class].imshow(img, cmap="Greys")
#     ax[i//points_per_class,i%points_per_class].set_title(f"action = {action_labels[i]}")

# %%
points_per_class = es_config["dataset_size"] // n_actions
points_per_class = min(10,points_per_class)

fig, ax = plt.subplots(10, points_per_class, figsize=(10,10))

for i, synth_state in enumerate(param_reshaper.reshape_single(sampled_data)):
    if i == 100:
        break
    img = synth_state.reshape(28,28)
    ax[i//points_per_class, i%points_per_class].imshow(img, cmap="Greys")
#     ax[i//points_per_class,i%points_per_class].set_title(f"action = {action_labels[i]}")

# %% [markdown]
# ## TODO:
#
# 1. Investigate nan / fitness computation for CartPole
#     - Division by zero if episodes not done

# %% [markdown]
# ## Generalization

# %% [markdown]
# ### TODO:
# - Turn this into function
# - Do this for both tanh and relu activations
# - Do this for multiple ES runs

# %%
width_list = [2,4,8,16,32,64,128,256,512,1024]
fit_list = {
            "relu" : [],
            "tanh" : []
           }
for width in width_list:
    new_config = config.copy()
    new_config["WIDTH"] = width
    new_config["UPDATE_EPOCHS"] = 10
    num_envs = 20
    
    fitness ={
            "relu" : -1,
            "tanh" : -1
           }
    
    for activation in ["relu", "tanh"]:
        new_config["ACTIVATION"] = activation

        final_dataset # Given
        action_labels # Given

        new_train_fn = make_train(new_config)

        def new_BC_train(rng_input, dataset):
            out = new_train_fn(dataset, action_labels, rng_input)
            return out  # ["metrics"]['returned_episode_returns'].mean()

        vmapped_BC_train = jax.jit(jax.vmap(new_BC_train, in_axes=(0, None)))

        rng, rng_new = jax.random.split(rng)
        rng_batch = jax.random.split(rng_new, num_envs)

        out_new = vmapped_BC_train(rng_batch, final_dataset)

        returns = out_new["metrics"]["returned_episode_returns"]  # dim=(popsize, rollout_news, num_steps, num_envs)
        dones = out_new["metrics"]["returned_episode"]  # same dim, True for last steps, False otherwise
        fitness[activation] = (returns * dones).sum(axis=(-1,-2)) / dones.sum(axis=(-1,-2))  # fitness, dim = (popsize)

        bc_loss = out_new['metrics']['bc_loss'][:,-1]

        fit_list[activation].append(fitness[activation])
    
    print(f"Width {width} : fitness (relu)={fitness['relu'].mean():.1f} +/- {fitness['relu'].std():.1f}, "
         + f"fitness (tanh)={fitness['tanh'].mean():.1f} +/- {fitness['tanh'].std():.1f}")

# %%
for activation, act_fit_list in fit_list.items():
    plt.scatter(width_list, [x.mean() for x in act_fit_list], label=activation)

    means = jnp.array([x.mean() for x in act_fit_list])
    stds = jnp.array([x.std() for x in act_fit_list])

    plt.errorbar(width_list, means, stds, alpha=0.5)
plt.ylabel("Fitness")
plt.xlabel("Network width (log scale)")
plt.xscale("log")
plt.xticks(width_list, width_list)

act = "greedy" if config["GREEDY_ACT"] else "softmax"
plt.title(f"Dataset transfer: {config['ENV_NAME']}, {act} (original: {config['ACTIVATION']}{config['WIDTH']})")
plt.legend()
plt.show()

# %% [markdown]
# ## Trying a hand-made dataset

# %%
# fake_dataset = jnp.array(
# [[0.2, -0.1, -0.1, -0.4],
# [1.0, 0.3, 0.6, 0.25]]
# )

# fig, ax = plt.subplots(1,2, figsize=(12,8))

# for i, synth_state in enumerate(fake_dataset):
#     img = render_fn(synth_state, env_params)
#     ax[i].imshow(img, label="hello")
#     ax[i].set_title(f"action = {action_labels[i]}")
    
#     x_dot = synth_state[1].item()
#     theta_dot = synth_state[3].item()
    
#     print(synth_state)
    
#     ax[i].set_xticks([0, 600/2, 600], [-4.8, 0, 4.8])
#     ax[i].text(490, 60, f"v={x_dot:.2f}, \ndθ={theta_dot:.2f}", bbox=dict(fill=False, edgecolor='red', linewidth=2))

# %%
# width_list = [2,4,8,16,32,64,128,256,512,1024]
# fit_list = {
#             "relu" : [],
#             "tanh" : []
#            }
# for width in width_list:
#     new_config = config.copy()
#     new_config["WIDTH"] = width
#     new_config["UPDATE_EPOCHS"] = 10
#     num_envs = 20
    
#     fitness ={
#             "relu" : -1,
#             "tanh" : -1
#            }
    
#     for activation in ["relu", "tanh"]:
#         new_config["ACTIVATION"] = activation

#         new_train_fn = make_train(new_config)

#         def new_BC_train(rng_input, dataset):
#             out = new_train_fn(dataset, action_labels, rng_input)
#             return out  # ["metrics"]['returned_episode_returns'].mean()

#         vmapped_BC_train = jax.jit(jax.vmap(new_BC_train, in_axes=(0, None)))

#         rng, rng_new = jax.random.split(rng)
#         rng_batch = jax.random.split(rng_new, num_envs)

#         out_new = vmapped_BC_train(rng_batch, fake_dataset)

#         returns = out_new["metrics"]["returned_episode_returns"]  # dim=(popsize, rollout_news, num_steps, num_envs)
#         dones = out_new["metrics"]["returned_episode"]  # same dim, True for last steps, False otherwise
#         fitness[activation] = (returns * dones).sum(axis=(-1,-2)) / dones.sum(axis=(-1,-2))  # fitness, dim = (popsize)

#         bc_loss = out_new['metrics']['bc_loss'][:,-1]

#         fit_list[activation].append(fitness[activation])
    
#     print(f"Width {width} : fitness (relu)={fitness['relu'].mean():.1f} +/- {fitness['relu'].std():.1f}, "
#          + f"fitness (tanh)={fitness['tanh'].mean():.1f} +/- {fitness['tanh'].std():.1f}")

# %%
# for activation, act_fit_list in fit_list.items():
#     plt.scatter(width_list, [x.mean() for x in act_fit_list], label=activation)

#     means = jnp.array([x.mean() for x in act_fit_list])
#     stds = jnp.array([x.std() for x in act_fit_list])

#     plt.errorbar(width_list, means, stds, alpha=0.5)
# plt.ylabel("Fitness")
# plt.xlabel("Network width (log scale)")
# plt.xscale("log")
# plt.xticks(width_list, width_list)
# plt.title(f"Dataset transfer (original: {config['ACTIVATION']}{config['WIDTH']} )")
# plt.legend()
# plt.show()
